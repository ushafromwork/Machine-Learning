# %% [markdown]
# <a href="https://colab.research.google.com/github/ushafromwork/Machine-Learning/blob/main/Mathematics_for_Machine_Learning_Vectors_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importance of Math:
#
# In ML mainly we need Data,Model and training the model, To understand the data we need to use some statistical measures.
#
# 1.Linear Algebra(Vectors,Matrices)
# 2.statistics
# 3.Calculus--differentiation,Integration probability
# 4.probability

# %% [markdown]
# #Vectors:
# We have three approaches for vectors
# vectors have both Magnitude and direction where as scalar has only magnitude
# 1.physics based approach:
#
# car speed=50km/hr no direction---scalar quantity
# speed=50km/hr North----Vector quantity
#
# 2.mathematical approach:
# vectors have both x and y axis--(-3,2) and (2,2). two vectors can have the same magnitude but different direction, two different vectors and same direction
#
# Magnitude of vector:sqrt(x1^2+x2^2)
# sqrt(2^2+2^2)=sqrt(8)
#
# Direction of vector:
# tanΘ=opposite/adjacent=2/2=1==45
#
#
#
# 3.computer science based approach:
# vector is n dimensional
# scalar is just a number or float
# vector=[2  -8  7] or in column

# %% [markdown]
# #Vector Operations-Part1

# %% [markdown]
# 1.vector addition
# 2.vector subtraction
# 3.multiplying a vector by a scalar
# 4.Angle between 2 vectors
#
# An array is a vector which contains multiple values
# Significance of vectors in ML:
#
# 1.Vector Addition:

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set() #it gives default theme

# %% [markdown]
# #Plotting vector

# %%
plt.quiver(0,0,4,5)
plt.show()

# %%
plt.quiver(0,0,4,5,scale_units='xy',angles='xy',scale=1) #0,0 base pint of vector
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %%
plt.quiver(0,0,4,5,scale_units='xy',angles='xy',scale=1,color='Blue') #0,0 base pint of vector
plt.quiver(0,0,-3,-6,scale_units='xy',angles='xy',scale=1,color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# #Addition of vectors

# %%
vector_1=np.asarray([0,0,2,3])
vector_2=np.asarray([0,0,3,-2])
sum=vector_1+vector_2
print(sum)
# Out:
# [0 0 5 1]

# %% [markdown]
# #Plotting the above vectors

# %%
plt.quiver(0,0,2,3,scale_units='xy',angles='xy',scale=1,color='Blue') #0,0 base pint of vector
plt.quiver(0,0,3,-2,scale_units='xy',angles='xy',scale=1,color='y')
plt.quiver(0,0,5,1,scale_units='xy',angles='xy',scale=1,color='g')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# #Subtraction of 2 vectors

# %%
vector_1=np.asarray([0,0,2,3])
vector_2=np.asarray([0,0,3,-2])
sub=vector_1-vector_2
print(sub)
# Out:
# [ 0  0 -1  5]

# %% [markdown]
# #Plotting subtraction of vectors

# %%
plt.quiver(0,0,2,3,scale_units='xy',angles='xy',scale=1,color='Blue') #0,0 base pint of vector
plt.quiver(0,0,3,-2,scale_units='xy',angles='xy',scale=1,color='y')
plt.quiver(0,0,-1,5,scale_units='xy',angles='xy',scale=1,color='r')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# #Multiplying a vector by a scalar

# %%
vector_1=np.asarray([0,0,2,3])
mul=2*vector_1
print(mul)
# Out:
# [0 0 4 6]

# %% [markdown]
# #Plotting multiplication of vector by a scalar

# %%
plt.quiver(0,0,2,3,scale_units='xy',angles='xy',scale=1,color='Blue') #0,0 base pint of vector
plt.quiver(0,0,4,6,scale_units='xy',angles='xy',scale=1,color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %%
vector_1=np.asarray([0,0,2,3])
mul=-0.5*vector_1
print(mul)
# Out:
# [-0.  -0.  -1.  -1.5]

# %%
plt.quiver(0,0,2,3,scale_units='xy',angles='xy',scale=1,color='Blue') #0,0 base pint of vector
plt.quiver(0,0,-1,-1.5,scale_units='xy',angles='xy',scale=1,color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()
