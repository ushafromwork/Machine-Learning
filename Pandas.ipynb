# %% [markdown]
# <a href="https://colab.research.google.com/github/ushafromwork/Machine-Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Library: Useful for data processing and analysis
# pandas library contains two important object types.
#
# 1)pandas data frame:
# Pandas data frame is two dimensional tabular data structure with labeled axes(rows and columns)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# creating a pandas DataFrame

# %%
#importing the boston house price data
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()
print(housing)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
#Pandas dataframe
cal_df=pd.DataFrame(housing.data,columns= housing.feature_names)

cal_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
print(cal_df.shape)
# Out:
# (20640, 8)

# %% [markdown]
# Importing the data from a csv file to a panda data frame

# %%
diabetes_df=pd.read_csv('/diabetes.csv')
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Loading the data from a excel file to pandas data frame
#pd.read_excel(''filepath)
#Exporting  a data frame to csv file
cal_df.to_csv('california.csv')

# %% [markdown]
# Exporting a dataframe to excel file
# cal._df.to_excel('filename')

# %%
#creating a DataFrame with random values
random_df=pd.DataFrame(np.random.rand(20,10))
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.518428  0.907095  0.937542  0.071108  0.996862  0.738943  0.053289
# 1  0.142035  0.606554  0.156402  0.450467  0.413922  0.346969  0.812423
# 2  0.706449  0.608741  0.792764  0.695802  0.243889  0.622516  0.235084
# 3  0.885505  0.255703  0.405903  0.446452  0.660605  0.656413  0.200860
# 4  0.120058  0.981726  0.150174  0.130673  0.668584  0.491711  0.106021
#
#           7         8         9
# 0  0.788685  0.077361  0.337091
# 1  0.117241  0.294776  0.720101
# 2  0.506983  0.115955  0.891088
# 3  0.293538  0.545676  0.365207
# 4  0.086170  0.228349  0.453143

# %% [markdown]
# Inspecting a Data Frame

# %%
#finding the rows and columns
random_df.shape
# Out:
# (20, 10)

# %%
#finding first 5 rows
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.518428  0.907095  0.937542  0.071108  0.996862  0.738943  0.053289
# 1  0.142035  0.606554  0.156402  0.450467  0.413922  0.346969  0.812423
# 2  0.706449  0.608741  0.792764  0.695802  0.243889  0.622516  0.235084
# 3  0.885505  0.255703  0.405903  0.446452  0.660605  0.656413  0.200860
# 4  0.120058  0.981726  0.150174  0.130673  0.668584  0.491711  0.106021
#
#           7         8         9
# 0  0.788685  0.077361  0.337091
# 1  0.117241  0.294776  0.720101
# 2  0.506983  0.115955  0.891088
# 3  0.293538  0.545676  0.365207
# 4  0.086170  0.228349  0.453143

# %%
#last 5 rows of data frame
random_df.tail()
# Out:
#            0         1         2         3         4         5         6  \
# 15  0.844356  0.386909  0.500933  0.472529  0.252694  0.576121  0.795672
# 16  0.600801  0.246258  0.758594  0.053119  0.355408  0.302503  0.756908
# 17  0.475772  0.979275  0.552250  0.465000  0.746959  0.330399  0.721541
# 18  0.582722  0.346694  0.850325  0.343946  0.661081  0.010669  0.407258
# 19  0.484178  0.082076  0.887317  0.538089  0.701940  0.714490  0.898141
#
#            7         8         9
# 15  0.386868  0.170510  0.963056
# 16  0.706941  0.989601  0.585589
# 17  0.142531  0.976018  0.615087
# 18  0.179035  0.383499  0.191422
# 19  0.021108  0.082149  0.485243

# %%
#information about data frame
random_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20 non-null     float64
#  1   1       20 non-null     float64
#  2   2       20 non-null     float64
#  3   3       20 non-null     float64
#  4   4       20 non-null     float64
#  5   5       20 non-null     float64
#  6   6       20 non-null     float64
#  7   7       20 non-null     float64
#  8   8       20 non-null     float64
#  9   9       20 non-null     float64
# dtypes: float64(10)
# memory usage: 1.7 KB

# %%
#finding the no.of missing values
random_df.isnull
# Out:
# <bound method DataFrame.isnull of            0         1         2         3         4         5         6  \
# 0   0.518428  0.907095  0.937542  0.071108  0.996862  0.738943  0.053289
# 1   0.142035  0.606554  0.156402  0.450467  0.413922  0.346969  0.812423
# 2   0.706449  0.608741  0.792764  0.695802  0.243889  0.622516  0.235084
# 3   0.885505  0.255703  0.405903  0.446452  0.660605  0.656413  0.200860
# 4   0.120058  0.981726  0.150174  0.130673  0.668584  0.491711  0.106021
# 5   0.763059  0.421538  0.080748  0.660797  0.901373  0.438526  0.103346
# 6   0.772369  0.763537  0.719974  0.018869  0.617964  0.863805  0.079526
# 7   0.548682  0.699358  0.107153  0.527375  0.885142  0.409104  0.308018
# 8   0.371095  0.525760  0.859519  0.766279  0.702599  0.339200  0.783839
# 9   0.040941  0.102673  0.496344  0.414959  0.142903  0.025613  0.387111
# 10  0.763776  0.609239  0.787081  0.141564  0.779788  0.706881  0.742953
# ...

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#counting the values based on labels
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
#Group the values based on the mean
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical Measures

# %%
#count or number of values
cal_df.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# dtype: int64

# %%
# mean value -column wise
cal_df.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
#standard deviation-column wise
cal_df.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# dtype: float64

# %%
#Minimum value and maximum value
cal_df.min()
# Out:
# MedInc          0.499900
# HouseAge        1.000000
# AveRooms        0.846154
# AveBedrms       0.333333
# Population      3.000000
# AveOccup        0.692308
# Latitude       32.540000
# Longitude    -124.350000
# dtype: float64

# %%
cal_df.max()
# Out:
# MedInc           15.000100
# HouseAge         52.000000
# AveRooms        141.909091
# AveBedrms        34.066667
# Population    35682.000000
# AveOccup       1243.333333
# Latitude         41.950000
# Longitude      -114.310000
# dtype: float64

# %%
#All the statistical measures about the dataframe
cal_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %% [markdown]
# manipulating a Data frame

# %%
# adding a column to a dataframe
cal_df['Price']=housing.target
cal_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
#removing a row
cal_df.drop(index=0,axis=0)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 1        -122.22
# ...

# %%
#removing a column
cal_df.drop(columns='MedInc',axis=1)
# Out:
#        HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0          41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1          21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2          52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3          52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4          52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...         ...       ...        ...         ...       ...       ...
# 20635      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# ...

# %%
#locating a row using the index value
cal_df.iloc[2]
# Out:
# MedInc          7.257400
# HouseAge       52.000000
# AveRooms        8.288136
# AveBedrms       1.073446
# Population    496.000000
# AveOccup        2.802260
# Latitude       37.850000
# Longitude    -122.240000
# Name: 2, dtype: float64

# %%
#locationg a particular column
cal_df.iloc[:,0]# first column
cal_df.iloc[:,1]
cal_df.iloc[:,2]
cal_df.iloc[:,-1]#last column
# Out:
# 0       -122.23
# 1       -122.22
# 2       -122.24
# 3       -122.25
# 4       -122.25
#           ...
# 20635   -121.09
# 20636   -121.21
# 20637   -121.22
# 20638   -121.32
# 20639   -121.24
# Name: Longitude, Length: 20640, dtype: float64

# %% [markdown]
# Correlation:
# 1.Positive (If increment of one value increases another value)
# 2.Negative(If increment of one value decreases another value)

# %%
cal_df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
#
#             Latitude  Longitude
# MedInc     -0.079809  -0.015176
# HouseAge    0.011173  -0.108197
# AveRooms    0.106389  -0.027540
# AveBedrms   0.069721   0.013344
# Population -0.108785   0.099773
# AveOccup    0.002366   0.002476
# Latitude    1.000000  -0.924664
# Longitude  -0.924664   1.000000
